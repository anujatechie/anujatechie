# %%
a=int(input("Enter your first integer Number :"))
b=int(input("Enter your second integer Number "))
print ("**********print three lines **********")
print("Sumission", a+b)
print("Subtraction", a-b)
print("Product", a*b)
# Out:
# Enter your first integer Number :4
# Enter your second integer Number 2
# **********print three lines **********
# Sumission 6
# Subtraction 2
# Product 8

# %%
"""Read two integers and print two lines. The first line should contain integer division,  // . The second line should contain float division"""
a=input("Enter your first integer Number :")
b=input("Enter your second integer Number ")

print("Integer Devision is " , m // n)
print("Float division " , m / n)
# Out:
# Enter your first integer Number :80
# Enter your second integer Number 5
# Integer Devision is  16
# Float division  16.0

# %%
"""Given an integer, n , perform the following conditional actions:
If  is odd, print Weird
If  is even and in the inclusive range of 2 to 5, print Not Weird
If  is even and in the inclusive range of 6 to 20 , print Weird
If  is even and greater than 20 , print Not Weird
"""


n=int(input("Enter Value for N "))
#x=int((n/2)*2)
if n%2!=0 :
  print("Weird")
elif (2<=n<=5) :
  print("Not Weird")
elif (n >=6 ) & (n<=20) :
  print("Weird*")  
elif (n>20) :
  print("Not Weird**")
# Out:
# Enter Value for N 22
# Not Weird**

# %% [markdown]
# # Passord Validation Program in Python

# %%
# Python program to check validation of password 
# Module of regular expression is used with search() 
import re 
password = input("Please enter your password: ")
flag = 0
while True:   
    if (len(password)<10): 
        flag = -1
        break
    elif not re.search("[a-z]", password): 
        flag = -1
        break
    elif not re.search("[A-Z]", password): 
        flag = -1
        break
    elif not re.search("[0-9]", password): 
        flag = -1
        break
    elif not re.search("[_@$^]", password): 
        flag = -1
        break
    elif re.search("\s", password): 
        flag = -1
        break
        
    else: 
        flag = 0
        print("Valid Password") 
        break
  
if flag ==-1: 
    print("Not a Valid Password")
# Out:
# Please enter your password: Gaurav^2019
# Valid Password

# %%
password = input("Please enter your password: ")
flag = 0
while True:
      if (len(password)<10): 
        flag = -1
        break
      elif not ( password  like "[a-z]"): 
        flag = -1
        break
      else: 
        flag = 0
        print("Valid Password") 
        break
if flag ==-1: 
    print("Not a Valid Password")
# Out:
#   File "<ipython-input-14-29f3da901de0>", line 7
#     elif not ( password  like "[a-z]"):
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # **Frequency of Character**

# %%
text1=str(input())
# Out:
# One
